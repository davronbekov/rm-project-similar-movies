# %%
import numpy as np
import pandas as pd

# %%
dataset_path = './drive/MyDrive/Colab Notebooks/itv/dataset/'

# %%
import os

os.listdir(dataset_path)
# Out:
# ['cards.csv',
#  'card_actors.csv',
#  'card_countries.csv',
#  'card_directors.csv',
#  'card_genres.csv',
#  'card_producers.csv',
#  'card_scenarists.csv',
#  'countries.csv',
#  'genres.csv',
#  'people.csv',
#  '.ipynb_checkpoints',
#  'tfidf_matrix.pkl',
#  'movie_list.pkl']

# %%
people = pd.read_csv(f'{dataset_path}people.csv')
people.head(2)
# Out:
#    id  photo_id                name  gender  dbd  country_id  \
# 0   1    6738.0     Сарик Андреасян     NaN  NaN         NaN
# 1   2    1373.0  Владимир Зеленский     NaN  NaN         NaN
#
#             created_at           updated_at
# 0  2019-01-02 16:20:52  2023-04-04 02:43:45
# 1  2019-01-02 16:20:52  2023-04-04 02:43:45

# %%
def group_elements(data, columns):
  return data.groupby(columns).agg(lambda x: list(x))

# %%
def merge_elements(data_left, data_right, column_left, column_right):
  return data_left.merge(data_right, left_on=column_left, right_on=column_right)

# %%
def collapse(data):
    items = []
    for i in data:
        items.append(i.replace(" ",""))
    return items

# %%
card_actors = pd.read_csv(f'{dataset_path}card_actors.csv')

card_actors = merge_elements(card_actors, people, 'person_id', 'id')[['content_id', 'person_id', 'name']]
card_actors.head()
# Out:
#    content_id  person_id          name
# 0           1       4192  Деннис Куэйд
# 1         542       4192  Деннис Куэйд
# 2         656       4192  Деннис Куэйд
# 3         684       4192  Деннис Куэйд
# 4        1543       4192  Деннис Куэйд

# %%
card_directors = pd.read_csv(f'{dataset_path}card_directors.csv')

card_directors = merge_elements(card_directors, people, 'person_id', 'id')[['content_id', 'person_id', 'name']]
card_directors.head()
# Out:
#    content_id  person_id              name
# 0           1      17496  Габриэле Муччино
# 1        1401      17496  Габриэле Муччино
# 2       11055      17496  Габриэле Муччино
# 3       43358      17496  Габриэле Муччино
# 4           2      24731     Виктор Гарсия

# %%
card_producers = pd.read_csv(f'{dataset_path}card_producers.csv')

card_producers = merge_elements(card_producers, people, 'person_id', 'id')[['content_id', 'person_id', 'name']]
card_producers.head()
# Out:
#    content_id  person_id            name
# 0           1       4200  Джерард Батлер
# 1        3414       4200  Джерард Батлер
# 2        8688       4200  Джерард Батлер
# 3       11361       4200  Джерард Батлер
# 4       13699       4200  Джерард Батлер

# %%
card_scenarists = pd.read_csv(f'{dataset_path}card_scenarists.csv')

card_scenarists = merge_elements(card_scenarists, people, 'person_id', 'id')[['content_id', 'person_id', 'name']]
card_scenarists.head()
# Out:
#    content_id  person_id        name
# 0           1      27111  Робби Фокс
# 1       77849      27111  Робби Фокс
# 2           2      19867   Робб Уайт
# 3        1641      19867   Робб Уайт
# 4        3068      19867   Робб Уайт

# %%
card_actors = group_elements(card_actors, ['content_id'])
card_directors = group_elements(card_directors, ['content_id'])
card_producers = group_elements(card_producers, ['content_id'])
card_scenarists = group_elements(card_scenarists, ['content_id'])

# %%
card_actors.head(3)
# Out:
#                                                     person_id  \
# content_id
# 1           [4192, 4200, 838, 11421, 7753, 1295, 27113, 27...
# 2           [8017, 20677, 13715, 8537, 4284, 10581, 17152,...
# 3           [2543, 14495, 2590, 1117, 1510, 6786, 2317, 29...
#
#                                                          name
# content_id
# 1           [Деннис Куэйд, Джерард Батлер, Джессика Бил, Д...
# 2           [Аманда Ри, Джил Колирин, Том Райли, Эндрю Ли ...
# 3           [Вуди Харрельсон, Желько Иванек, Колин Фаррелл...

# %%
card_directors.head(3)
# Out:
#            person_id                name
# content_id
# 1            [17496]  [Габриэле Муччино]
# 2            [24731]     [Виктор Гарсия]
# 3            [25960]    [Мартин МакДона]

# %%
card_producers.head(3)
# Out:
#                         person_id  \
# content_id
# 1             [4200, 6587, 27112]
# 2           [20041, 27118, 27119]
# 3           [20253, 21940, 25960]
#
#                                                         name
# content_id
# 1            [Джерард Батлер, Кевин Мишер, Хайди Джо Маркел]
# 2                     [Стив Ричардс, Эрик Олсен, Роуи Шэрон]
# 3           [Грэхэм Броадбент, Питер Чернин, Мартин МакДона]

# %%
card_scenarists.head(3)
# Out:
#                  person_id                       name
# content_id
# 1                  [27111]               [Робби Фокс]
# 2           [19867, 27117]  [Робб Уайт, Уильям Масса]
# 3                  [25960]           [Мартин МакДона]

# %%
genres = pd.read_csv(f'{dataset_path}genres.csv')
genres.head(5)
# Out:
#    id   identify  priority           created_at           updated_at
# 0   0  Все жанры         0  2019-01-02 16:19:24  2023-02-08 02:32:23
# 1   1      Аниме        33  2019-01-02 16:19:24  2023-02-08 02:32:41
# 2   2  Биография        37  2019-01-02 16:19:24  2023-02-08 02:32:44
# 3   3     Боевик        39  2019-01-02 16:19:24  2023-02-08 02:32:45
# 4   4    Вестерн        43  2019-01-02 16:19:24  2023-02-08 02:32:48

# %%
card_genres = pd.read_csv(f'{dataset_path}card_genres.csv')

card_genres = merge_elements(card_genres, genres, 'genre_id', 'id')[['content_id', 'genre_id', 'identify']]
card_genres.head()
# Out:
#    content_id  genre_id identify
# 0           1        12  Комедия
# 1           3        12  Комедия
# 2          10        12  Комедия
# 3          11        12  Комедия
# 4          16        12  Комедия

# %%
card_genres = group_elements(card_genres, ['content_id'])
# card_countries = group_elements(card_countries, ['content_id'])

# %%
card_genres.head(3)
# Out:
#             genre_id              identify
# content_id
# 1           [12, 15]  [Комедия, Мелодрама]
# 2           [30, 31]      [Триллер, Ужасы]
# 3           [12, 14]   [Комедия, Криминал]

# %%
# card_countries.head(3)

# %%
card_actors['actors'] = card_actors['name']
card_directors['directors'] = card_directors['name']
card_producers['producers'] = card_producers['name']
card_scenarists['scenarists'] = card_scenarists['name']

# %%
card_actors.drop(['person_id', 'name'], axis=1, inplace=True)
card_directors.drop(['person_id', 'name'],axis=1, inplace=True)
card_producers.drop(['person_id', 'name'], axis=1, inplace=True)
card_scenarists.drop(['person_id', 'name'], axis=1, inplace=True)

# %%
cards = pd.read_csv(f'{dataset_path}cards.csv')

# %%
cards = merge_elements(cards, card_actors, 'id', 'content_id')
cards = merge_elements(cards, card_directors, 'id', 'content_id')
cards = merge_elements(cards, card_producers, 'id', 'content_id')
cards = merge_elements(cards, card_scenarists, 'id', 'content_id')

# %%
cards = cards[['id', 'module_id', 'payment_module', 'title', 'title_eng', 'description', 'tasix', 'vpn', 'actors', 'directors', 'producers', 'scenarists']]

# %%
cards.head(3)
# Out:
#      id  module_id  payment_module                      title  \
# 0   512          2              20                      Скала
# 1   768          2              20  Южный Парк: Воображляндия
# 2  1024          2              20                      Ронин
#
#                      title_eng  \
# 0                     The Rock
# 1  South Park: Imaginationland
# 2                        Ronin
#
#                                          description  tasix  vpn  \
# 0  Генерал элитных диверсионных спецсил США Френс...      1    0
# 1  <p>Парней из Южного Парка отправляют в волшебн...      1    0
# 2  <p>Хотя холодная война давно закончена, тайные...      1    0
#
#                                               actors             directors  \
# 0  [Николас Кейдж, Дэвид Морс, Ванесса Марсил, Гр...           [Майкл Бэй]
# 1  [Джонатан Киммел, Кайл Маккаллок, Кэтрин Хауэл...         [Трей Паркер]
# 2  [Шон Бин, Роберт Де Ниро, Джонатан Прайс, Жан ...  [Джон Франкенхаймер]
#
#                                          producers  \
# 0    [Джерри Брукхаймер, Кенни Бейтс, Шон Коннери]
# 1             [Пэм Брэйди, Эдриан Бирд, Эрик Стоф]
# 2  [Пол Келменсон, Фрэнк Манкузо мл, Этель Уинант]
#
#                                   scenarists
# 0  [Дуглас Кук, Дэвид Уайсберг, Марк Роснер]
# 1                  [Мэтт Стоун, Трей Паркер]
# 2                 [Дэвид Мэмет, Дж. Д. Зайк]

# %%
card_genres['genres'] = card_genres['identify']

card_genres.drop(['genre_id', 'identify'], axis=1, inplace=True)

# %%
card_genres.head(3)
# Out:
#                           genres
# content_id
# 1           [Комедия, Мелодрама]
# 2               [Триллер, Ужасы]
# 3            [Комедия, Криминал]

# %%
cards = merge_elements(cards, card_genres, 'id', 'content_id')

# %%
cards.head(5)
# Out:
#      id  module_id  payment_module                      title  \
# 0   512          2              20                      Скала
# 1   768          2              20  Южный Парк: Воображляндия
# 2  1024          2              20                      Ронин
# 3  1536          2              20                     Аватар
# 4  1792          2              20                      Между
#
#                      title_eng  \
# 0                     The Rock
# 1  South Park: Imaginationland
# 2                        Ronin
# 3                       Avatar
# 4                        Twixt
#
#                                          description  tasix  vpn  \
# 0  Генерал элитных диверсионных спецсил США Френс...      1    0
# 1  <p>Парней из Южного Парка отправляют в волшебн...      1    0
# 2  <p>Хотя холодная война давно закончена, тайные...      1    0
# 3  Джейк Салли — бывший морской пехотинец, приков...      1    0
# 4  <p>Потерявший вдохновение писатель приезжает в...      1    0
#
#                                               actors               directors  \
# 0  [Николас Кейдж, Дэвид Морс, Ванесса Марсил, Гр...             [Майкл Бэй]
# 1  [Джонатан Киммел, Кайл Маккаллок, Кэтрин Хауэл...           [Трей Паркер]
# 2  [Шон Бин, Роберт Де Ниро, Джонатан Прайс, Жан ...    [Джон Франкенхаймер]
# 3  [Уэс Стьюди, Стивен Лэнг, Джованни Рибизи, Зои...        [Джеймс Кэмерон]
# 4  [Эль Фаннинг, Брюс Дерн, Вэл Килмер, Дэвид Пэй...  [Френсис Форд Коппола]
#
#                                          producers  \
# 0    [Джерри Брукхаймер, Кенни Бейтс, Шон Коннери]
# 1             [Пэм Брэйди, Эдриан Бирд, Эрик Стоф]
# 2  [Пол Келменсон, Фрэнк Манкузо мл, Этель Уинант]
# 3       [Джеймс Кэмерон, Джон Ландау, Брук Бретон]
# 4  [Френсис Форд Коппола, Джош Гриффит, Джим Хэйс]
#
#                                   scenarists  \
# 0  [Дуглас Кук, Дэвид Уайсберг, Марк Роснер]
# 1                  [Мэтт Стоун, Трей Паркер]
# 2                 [Дэвид Мэмет, Дж. Д. Зайк]
# 3                           [Джеймс Кэмерон]
# 4                     [Френсис Форд Коппола]
#
#                                      genres
# 0                         [Триллер, Боевик]
# 1                        [Комедия, Фэнтези]
# 2               [Триллер, Криминал, Боевик]
# 3  [Боевик, Драма, Приключения, Фантастика]
# 4                 [Триллер, Ужасы, Фэнтези]

# %%
cards.isna()
# Out:
#           id  module_id  payment_module  title  title_eng  description  tasix  \
# 0      False      False           False  False      False        False  False
# 1      False      False           False  False      False        False  False
# 2      False      False           False  False      False        False  False
# 3      False      False           False  False      False        False  False
# 4      False      False           False  False      False        False  False
# ...      ...        ...             ...    ...        ...          ...    ...
# 23518  False      False           False  False      False        False  False
# 23519  False      False           False  False      False        False  False
# 23520  False      False           False  False      False        False  False
# 23521  False      False           False  False      False        False  False
# 23522  False      False           False  False      False        False  False
#
#          vpn  actors  directors  producers  scenarists  genres
# 0      False   False      False      False       False   False
# 1      False   False      False      False       False   False
# 2      False   False      False      False       False   False
# 3      False   False      False      False       False   False
# 4      False   False      False      False       False   False
# ...      ...     ...        ...        ...         ...     ...
# 23518  False   False      False      False       False   False
# 23519  False   False      False      False       False   False
# 23520  False   False      False      False       False   False
# 23521  False   False      False      False       False   False
# 23522  False   False      False      False       False   False
#
# [23523 rows x 13 columns]

# %%
cards['actors'] = cards['actors'].apply(collapse)
cards['directors'] = cards['directors'].apply(collapse)
cards['producers'] = cards['producers'].apply(collapse)
cards['scenarists'] = cards['scenarists'].apply(collapse)
cards['genres'] = cards['genres'].apply(collapse)

# %%
cards.head(5)
# Out:
#      id  module_id  payment_module                      title  \
# 0   512          2              20                      Скала
# 1   768          2              20  Южный Парк: Воображляндия
# 2  1024          2              20                      Ронин
# 3  1536          2              20                     Аватар
# 4  1792          2              20                      Между
#
#                      title_eng  \
# 0                     The Rock
# 1  South Park: Imaginationland
# 2                        Ronin
# 3                       Avatar
# 4                        Twixt
#
#                                          description  tasix  vpn  \
# 0  Генерал элитных диверсионных спецсил США Френс...      1    0
# 1  <p>Парней из Южного Парка отправляют в волшебн...      1    0
# 2  <p>Хотя холодная война давно закончена, тайные...      1    0
# 3  Джейк Салли — бывший морской пехотинец, приков...      1    0
# 4  <p>Потерявший вдохновение писатель приезжает в...      1    0
#
#                                               actors             directors  \
# 0  [НиколасКейдж, ДэвидМорс, ВанессаМарсил, Грего...            [МайклБэй]
# 1  [ДжонатанКиммел, КайлМаккаллок, КэтринХауэлл, ...          [ТрейПаркер]
# 2  [ШонБин, РобертДеНиро, ДжонатанПрайс, ЖанРено,...   [ДжонФранкенхаймер]
# 3  [УэсСтьюди, СтивенЛэнг, ДжованниРибизи, ЗоиСал...       [ДжеймсКэмерон]
# 4  [ЭльФаннинг, БрюсДерн, ВэлКилмер, ДэвидПэймер,...  [ФренсисФордКоппола]
#
#                                      producers  \
# 0   [ДжерриБрукхаймер, КенниБейтс, ШонКоннери]
# 1            [ПэмБрэйди, ЭдрианБирд, ЭрикСтоф]
# 2  [ПолКелменсон, ФрэнкМанкузомл, ЭтельУинант]
# 3      [ДжеймсКэмерон, ДжонЛандау, БрукБретон]
# 4  [ФренсисФордКоппола, ДжошГриффит, ДжимХэйс]
#
#                                scenarists  \
# 0  [ДугласКук, ДэвидУайсберг, МаркРоснер]
# 1                 [МэттСтоун, ТрейПаркер]
# 2                 [ДэвидМэмет, Дж.Д.Зайк]
# 3                         [ДжеймсКэмерон]
# 4                    [ФренсисФордКоппола]
#
#                                      genres
# 0                         [Триллер, Боевик]
# 1                        [Комедия, Фэнтези]
# 2               [Триллер, Криминал, Боевик]
# 3  [Боевик, Драма, Приключения, Фантастика]
# 4                 [Триллер, Ужасы, Фэнтези]

# %%
cards[cards['title_eng'].isnull()]
# Out:
#           id  module_id  payment_module                title title_eng  \
# 7       2816          2              20              Рэкетир       NaN
# 9       3584          2              20  Жила-была одна баба       NaN
# 10      3840          2              20   Кавказский пленник       NaN
# 14      4864          2              20          Ширли-мырли       NaN
# 32     78336          2              28     Больше, чем кино       NaN
# ...      ...        ...             ...                  ...       ...
# 23006  79615         10              11            Барабашка       NaN
# 23009  31231         10              20                  Коп       NaN
# 23012  42239         10              11           Территория       NaN
# 23014  45311         10              20  Нагиев на каникулах       NaN
# 23015  48383         10              20           Угрюм-река       NaN
#
#                                              description  tasix  vpn  \
# 7      <p>Это биографическая история о жизни молодого...      1    0
# 9      <p>История частной жизни одной женщины и четве...      1    0
# 10     <p>На Кавказе &#151; война. Двух раненых русск...      1    0
# 14     <p>Невероятная история о братьях &#151; близне...      1    0
# 32     Молодой режиссёр безуспешно старается найти фи...      1    0
# ...                                                  ...    ...  ...
# 23006  Артём сидит дома на карантине. Поначалу ему да...      1    0
# 23009  Лейтенанта полиции Колю отправляют в Америку, ...      1    0
# 23012  19-летний Егор Чудинов отправляется на поиски ...      1    0
# 23014  Карантин прошёл и случилось то, чего так долго...      1    0
# 23015  История трех поколений семьи Громовых. Главный...      0    0
#
#                                                   actors  \
# 7      [МуратБисенбин, СаятИсембаев, ВладимирВдовичен...
# 9      [АлексейСеребряков, МаксимАверин, ВладиславАба...
# 10     [ОлегМеньшиков, СергейБодровмл., АлексейЖарков...
# 14     [ИгорьУгольников, АрменДжигарханян, ОлегТабако...
# 32     [АружанДжазильбекова, ЖанияЖуринская, ДаниярАл...
# ...                                                  ...
# 23006  [МаксимЛагашкин, ЕвгенийМуравич, ТимофейТрибун...
# 23009  [ДмитрийБлохин, АннаСнаткина, НиколайКозак, Ек...
# 23012  [АндрейМерзликин, АлексейРозин, КлавдияКоршуно...
# 23014  [ДмитрийНагиев, ЕлизаветаМоряк, АртемСуджян, Р...
# 23015  [АлександрБалуев, БорисКаморзин, ЮлияПересильд...
#
#                                                directors  \
# 7                                           [АканСатаев]
# 9                                        [АндрейСмирнов]
# 10                                        [СергейБодров]
# 14                                     [ВладимирМеньшов]
# 32                                       [АскарБисембин]
# ...                                                  ...
# 23006                             [АлександрСобичевский]
# 23009  [РаддаНовикова, АлександрЦекало, АнтонБорисов,...
# 23012                                [ИгорьТвердохлебов]
# 23014                                   [СарикАндреасян]
# 23015                                        [ЮрийМороз]
#
#                                                producers  \
# 7                                           [АканСатаев]
# 9        [АндрейСмирнов, ЕленаПрудникова, АннаКаминская]
# 10         [СергейБодров, КэролинКавальеро, БорисГиллер]
# 14                  [ВладимирДосталь, АлександрЛитвинов]
# 32                                       [АскарБисембин]
# ...                                                  ...
# 23006  [ВалерийФедорович, АлександрПлотников, БорисХл...
# 23009  [АлександраРемизова, АлександрЦекало, ИванСамо...
# 23012            [АнтонЗайцев, АнтонЩукин, АртемЛогинов]
# 23014                      [СарикАндреасян, АртемСуджян]
# 23015                 [КонстантинЭрнст, ДенисЕвстигнеев]
#
#                                               scenarists  \
# 7                                      [ТимурЖаксылыков]
# 9                                        [АндрейСмирнов]
# 10                [СергейБодров, АрифАлиев, БорисГиллер]
# 14     [ВиталийМоскаленко, АндрейСамсонов, ВладимирМе...
# 32     [АскарБисембин, СакенТоктагулов, ВасилийЗемзюлин]
# ...                                                  ...
# 23006  [АлександрСобичевский, ОльгаДибцева, ГлебХлебн...
# 23009  [АлександрЦекало, АнтонБорисов, ЛикаМаксимова,...
# 23012                               [АнастасияСамойлова]
# 23014                                   [ЛеонидМарголин]
# 23015                   [МарияСапрыкина, ВячеславШишков]
#
#                           genres
# 7      [Криминал, Боевик, Драма]
# 9               [Драма, История]
# 10              [Драма, Военный]
# 14                     [Комедия]
# 32                     [Комедия]
# ...                          ...
# 23006                  [Комедия]
# 23009        [Комедия, Детектив]
# 23012           [Триллер, Драма]
# 23014                  [Комедия]
# 23015                    [Драма]
#
# [4199 rows x 13 columns]

# %%
cards['title_eng'].fillna(cards['title'], inplace=True)
cards[cards['title_eng'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, module_id, payment_module, title, title_eng, description, tasix, vpn, actors, directors, producers, scenarists, genres]
# Index: []

# %%
cards['title_new'] = cards['title'].apply(lambda x:x.split(' '))
cards['title_eng_new'] = cards['title_eng'].apply(lambda x:x.split(' '))

# %%
import re

def remove_html(string):
    regex = re.compile(r'<[^>]+>')
    
    return regex.sub('', string)

# %%
cards['description'].fillna(cards['title'], inplace=True)

# %%
cards['description'] = cards['description'].apply(remove_html)
cards['description'] = cards['description'].apply(lambda x:x.split())

# %%
cards.head(5)
# Out:
#      id  module_id  payment_module                      title  \
# 0   512          2              20                      Скала
# 1   768          2              20  Южный Парк: Воображляндия
# 2  1024          2              20                      Ронин
# 3  1536          2              20                     Аватар
# 4  1792          2              20                      Между
#
#                      title_eng  \
# 0                     The Rock
# 1  South Park: Imaginationland
# 2                        Ronin
# 3                       Avatar
# 4                        Twixt
#
#                                          description  tasix  vpn  \
# 0  [Генерал, элитных, диверсионных, спецсил, США,...      1    0
# 1  [Парней, из, Южного, Парка, отправляют, в, вол...      1    0
# 2  [Хотя, холодная, война, давно, закончена,, тай...      1    0
# 3  [Джейк, Салли, —, бывший, морской, пехотинец,,...      1    0
# 4  [Потерявший, вдохновение, писатель, приезжает,...      1    0
#
#                                               actors             directors  \
# 0  [НиколасКейдж, ДэвидМорс, ВанессаМарсил, Грего...            [МайклБэй]
# 1  [ДжонатанКиммел, КайлМаккаллок, КэтринХауэлл, ...          [ТрейПаркер]
# 2  [ШонБин, РобертДеНиро, ДжонатанПрайс, ЖанРено,...   [ДжонФранкенхаймер]
# 3  [УэсСтьюди, СтивенЛэнг, ДжованниРибизи, ЗоиСал...       [ДжеймсКэмерон]
# 4  [ЭльФаннинг, БрюсДерн, ВэлКилмер, ДэвидПэймер,...  [ФренсисФордКоппола]
#
#                                      producers  \
# 0   [ДжерриБрукхаймер, КенниБейтс, ШонКоннери]
# 1            [ПэмБрэйди, ЭдрианБирд, ЭрикСтоф]
# 2  [ПолКелменсон, ФрэнкМанкузомл, ЭтельУинант]
# 3      [ДжеймсКэмерон, ДжонЛандау, БрукБретон]
# 4  [ФренсисФордКоппола, ДжошГриффит, ДжимХэйс]
#
#                                scenarists  \
# 0  [ДугласКук, ДэвидУайсберг, МаркРоснер]
# 1                 [МэттСтоун, ТрейПаркер]
# 2                 [ДэвидМэмет, Дж.Д.Зайк]
# 3                         [ДжеймсКэмерон]
# 4                    [ФренсисФордКоппола]
#
#                                      genres                      title_new  \
# 0                         [Триллер, Боевик]                        [Скала]
# 1                        [Комедия, Фэнтези]  [Южный, Парк:, Воображляндия]
# 2               [Триллер, Криминал, Боевик]                        [Ронин]
# 3  [Боевик, Драма, Приключения, Фантастика]                       [Аватар]
# 4                 [Триллер, Ужасы, Фэнтези]                        [Между]
#
#                      title_eng_new
# 0                      [The, Rock]
# 1  [South, Park:, Imaginationland]
# 2                          [Ronin]
# 3                         [Avatar]
# 4                          [Twixt]

# %%
# cards['tags'] = cards['description'] + cards['genres'] + cards['countries'] + cards['actors'] + cards['directors'] + cards['producers'] + cards['scenarists']
cards['tags'] = cards['title_new'] + cards['title_eng_new'] + cards['description'] + cards['genres'] + cards['actors'] + cards['directors'] + cards['producers'] + cards['scenarists']

# %%
cards.head(3)
# Out:
#      id  module_id  payment_module                      title  \
# 0   512          2              20                      Скала
# 1   768          2              20  Южный Парк: Воображляндия
# 2  1024          2              20                      Ронин
#
#                      title_eng  \
# 0                     The Rock
# 1  South Park: Imaginationland
# 2                        Ronin
#
#                                          description  tasix  vpn  \
# 0  [Генерал, элитных, диверсионных, спецсил, США,...      1    0
# 1  [Парней, из, Южного, Парка, отправляют, в, вол...      1    0
# 2  [Хотя, холодная, война, давно, закончена,, тай...      1    0
#
#                                               actors            directors  \
# 0  [НиколасКейдж, ДэвидМорс, ВанессаМарсил, Грего...           [МайклБэй]
# 1  [ДжонатанКиммел, КайлМаккаллок, КэтринХауэлл, ...         [ТрейПаркер]
# 2  [ШонБин, РобертДеНиро, ДжонатанПрайс, ЖанРено,...  [ДжонФранкенхаймер]
#
#                                      producers  \
# 0   [ДжерриБрукхаймер, КенниБейтс, ШонКоннери]
# 1            [ПэмБрэйди, ЭдрианБирд, ЭрикСтоф]
# 2  [ПолКелменсон, ФрэнкМанкузомл, ЭтельУинант]
#
#                                scenarists                       genres  \
# 0  [ДугласКук, ДэвидУайсберг, МаркРоснер]            [Триллер, Боевик]
# 1                 [МэттСтоун, ТрейПаркер]           [Комедия, Фэнтези]
# 2                 [ДэвидМэмет, Дж.Д.Зайк]  [Триллер, Криминал, Боевик]
#
#                        title_new                    title_eng_new  \
# 0                        [Скала]                      [The, Rock]
# 1  [Южный, Парк:, Воображляндия]  [South, Park:, Imaginationland]
# 2                        [Ронин]                          [Ronin]
#
#                                                 tags
# 0  [Скала, The, Rock, Генерал, элитных, диверсион...
# 1  [Южный, Парк:, Воображляндия, South, Park:, Im...
# 2  [Ронин, Ronin, Хотя, холодная, война, давно, з...

# %%
# cards_new = cards.drop(columns=['description','genres','countries','actors','directors', 'producers', 'scenarists'])
cards_new = cards.drop(columns=['description','genres', 'actors','directors', 'producers', 'scenarists', 'title_new', 'title_eng_new'])

# %%
cards_new['tags'] = cards_new['tags'].apply(lambda x: " ".join(x))
cards_new.head()
# Out:
#      id  module_id  payment_module                      title  \
# 0   512          2              20                      Скала
# 1   768          2              20  Южный Парк: Воображляндия
# 2  1024          2              20                      Ронин
# 3  1536          2              20                     Аватар
# 4  1792          2              20                      Между
#
#                      title_eng  tasix  vpn  \
# 0                     The Rock      1    0
# 1  South Park: Imaginationland      1    0
# 2                        Ronin      1    0
# 3                       Avatar      1    0
# 4                        Twixt      1    0
#
#                                                 tags
# 0  Скала The Rock Генерал элитных диверсионных сп...
# 1  Южный Парк: Воображляндия South Park: Imaginat...
# 2  Ронин Ronin Хотя холодная война давно закончен...
# 3  Аватар Avatar Джейк Салли — бывший морской пех...
# 4  Между Twixt Потерявший вдохновение писатель пр...

# %%
cards_new.count()
# Out:
# id                23523
# module_id         23523
# payment_module    23523
# title             23523
# title_eng         23523
# tasix             23523
# vpn               23523
# tags              23523
# dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(cards_new['tags'])

tfidf_matrix.shape
# Out:
# (23523, 310509)

# %%
tfidf
# Out:
# TfidfVectorizer(stop_words='english')

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel
from numpy import linalg as LA

#Construct a reverse map of indices and movie titles
indices = pd.Series(cards.index, index=cards_new['id']).drop_duplicates()

# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(cardId):
    # Get the index of the movie that matches the title
    idx = indices[cardId]

    # Get the pairwsie similarity scores of all movies with that movie
    # cosine_sim = (tfidf_matrix @ tfidf_matrix.T)
    cosine_sim = linear_kernel(tfidf_matrix[idx], tfidf_matrix)
    
    sim_scores = np.array([[key, value] for key, value in enumerate(cosine_sim[0])])

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:10]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    print(cards_new[['id', 'title']].iloc[movie_indices])

# %%
indices.head()
# Out:
# id
# 512     0
# 768     1
# 1024    2
# 1536    3
# 1792    4
# dtype: int64

# %%
get_recommendations(36516)
# Out:
#           id                                              title
# 14571  39204                                  Yulduzlar jangi 9
# 11457   8396                   Звёздные войны: Пробуждение силы
# 6323   34416                              Миссия: невыполнима 3
# 5475   13409                   Звёздные Войны: Последние джедаи
# 17007  11500                        Звёздные войны: Силы судьбы
# 8773    1181                                            Супер 8
# 8182    8338  Звёздные войны: Эпизод 5 – Империя наносит отв...
# 16527  78745               ЛЕГО Звёздные войны: Летние каникулы
# 1010     531                                      Звездный путь

# %%
import pickle

pickle.dump(cards_new, open(f'{dataset_path}movie_list.pkl','wb'))
pickle.dump(tfidf_matrix, open(f'{dataset_path}tfidf_matrix.pkl','wb'))
